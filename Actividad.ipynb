# %% [markdown]
# <div style="text-align:center;">
#     <img src="https://storage.googleapis.com/ue-webcorp-pro-as/resources/static/images/ue-logo.png"/>
# </div>
#
# * Mauricio Gonzalo Calderon de la Barca Rodo
# * Guido Rosales Jesus
# * Hilda Rosa Galvez Leiva
# * Fabian Nicolas Alvarez Palacios

# %% [markdown]
# ### Importar Librerias
#
# En este bloque importamos las librerias para el trabajo con Data Frames y la visualizacion correspondiente de los datos.

# %%
# Librerías de Python para la manipulación de datos
import pandas as pd
# import numpy as np

# Para la visualización de datos
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# Estilo para las gráficas
plt.style.use("ggplot")
rcParams['figure.figsize'] = (12,  6)

# %% [markdown]
# ## 1. Cargar datos de cancer
#
# Carga de los datos.

# %%
df = pd.read_csv('./breast-cancer.csv')

# %% [markdown]
# En este dataset encontramos un conjunto de datos, clasificados de pacientes a los que se les analizo la

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# ## 2. Visualizar las columnas con las que cuenta el DF y de que tipo es cada una

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# Al utilizar el metodo info de pandas, podemos observar que solo la variable de Diagnostico es de tipo categorico, el resto son de tipo numerico.
#
# Ademas, se puede observar como todas las columnas no cuentan con valores nulos.

# %% [markdown]
# ## 3. Entender que informacion es la que almacena cada variable del DF
#
# Se creo un nuevo DF, donde traducimos al español, el nombre de cada variable/columna y agegamos una breve descripcion, para tratar de entender que es lo que contiene.

# %%
descripcion_variables_df = pd.read_csv('./Descripcion.csv')
descripcion_variables_df
# Out:
#                       Ingles                      Español  \
# 0                         id               Identificacion
# 1                  diagnosis                  Diagnostico
# 2                radius_mean               Radio Promedio
# 3               texture_mean             Textura Promedio
# 4             perimeter_mean           Perimetro Promedio
# 5                  area_mean                Area Promedio
# 6            smoothness_mean            Suavidad Promedio
# 7           compactness_mean          Compacidad Promedio
# 8             concavity_mean          Concabidad promedio
# 9        concave points_mean     Puntos Concavos Promedio
# 10             symmetry_mean            Simetria Promedio
# 11    fractal_dimension_mean   Dimensi¢n Fractal Promedio
# 12                 radius_se                     Radio SE
# 13                texture_se                   Textura SE
# 14              perimeter_se                 Perimetro Se
# ...

# %% [markdown]
# ## 4. Validar si tenemos variables duplicados

# %%
print(f'Numero de registros duplicados: {df.duplicated().sum()}')
# Out:
# Numero de registros duplicados: 0

# %% [markdown]
# Como resultado de este paso podemos observar, que el DF no cuenta con registros duplicados.

# %% [markdown]
# ### Eliminar el ID y Diagnostico

# %%
col = df.columns.drop('id')
df = df[col]
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# ### Convertimos el Diagnostico en una cadena mas descriptiva

# %%
df['diagnosis'] = df['diagnosis'].apply(lambda x: 'Maligno' if x == 'M' else 'Benigno')
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302   Benigno        17.99         10.38          122.80     1001.0
# 1      842517   Benigno        20.57         17.77          132.90     1326.0
# 2    84300903   Benigno        19.69         21.25          130.00     1203.0
# 3    84348301   Benigno        11.42         20.38           77.58      386.1
# 4    84358402   Benigno        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424   Benigno        21.56         22.39          142.00     1479.0
# 565    926682   Benigno        20.13         28.25          131.20     1261.0
# 566    926954   Benigno        16.60         28.08          108.30      858.1
# 567    927241   Benigno        20.60         29.33          140.10     1265.0
# 568     92751   Benigno         7.76         24.54           47.92      181.0
#
# ...

# %%
sns.scatterplot(x="radius_mean", y="compactness_mean", hue="diagnosis", data=df, palette="Dark2", s=80)
plt.title("Relación entre protein_concentration, flavanoids y la  target")
plt.xlabel('Magia')
plt.ylabel('Magia2')
plt.show()

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# Para cada columna en el DataFrame
for columna in df.columns:
    # Crear un boxplot para identificar outliers
    plt.figure()
    df.boxplot([columna])
    
    # Realizar una prueba de normalidad (D'Agostino and Pearson's)
    k2, p = normaltest(df[columna])
    alpha = 0.05
    if p < alpha:  
        print("La columna {} no sigue una distribución normal".format(columna))
    else:
        print("La columna {} sigue una distribución normal".format(columna))
# Out:
# La columna id no sigue una distribución normal
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\nicol\OneDrive - Universidad Europea de Madrid\Documents\UE\Estadistica\Clase 1\Actividad.ipynb Celda 22 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/nicol/OneDrive%20-%20Universidad%20Europea%20de%20Madrid/Documents/UE/Estadistica/Clase%201/Actividad.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> for columna in df.columns:
#       <a href='vscode-notebook-cell:/c%3A/Users/nicol/OneDrive%20-%20Universidad%20Europea%20de%20Madrid/Documents/UE/Estadistica/Clase%201/Actividad.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a>     # Crear un boxplot para identificar outliers
# ...
